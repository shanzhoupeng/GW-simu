# %%
import json

# %%
help(json)
# Out:
# Help on package json:
#
# NAME
#     json
#
# FILE
#     /Users/shyn/anaconda2/lib/python2.7/json/__init__.py
#
# MODULE DOCS
#     https://docs.python.org/library/json
#
# DESCRIPTION
#     JSON (JavaScript Object Notation) <http://json.org> is a subset of
#     JavaScript syntax (ECMA-262 3rd edition) used as a lightweight data
#     interchange format.
#
#     :mod:`json` exposes an API familiar to users of the standard library
#     :mod:`marshal` and :mod:`pickle` modules. It is the externally maintained
#     version of the :mod:`json` library contained in Python 2.6, but maintains
#     compatibility with Python 2.4 and Python 2.5 and (currently) has
#     significant performance advantages, even without using the optional C
#     extension for speedups.
#
#     Encoding basic Python object hierarchies::
#
#         >>> import json
#         >>> json.dumps(['foo', {'bar': ('baz', None, 1.0, 2)}])
#         '["foo", {"bar": ["baz", null, 1.0, 2]}]'
# ...

# %%
f=open("persist.raid.json",'r')
f2=open("persist.upgrades.json",'r')
f3=open("abbey.upgrades.json",'r')

# %%
a=f.read()
b=f2.read()
c=f3.read()

# %%
d=json.loads(c)

# %%
d
# Out:
# {u'trees': [{u'id': u'abbey.meditation',
#    u'is_instanced': False,
#    u'requirements': [{u'code': u'a',
#      u'currency_cost': [{u'amount': 0, u'type': u'gold'},
#       {u'amount': 4, u'type': u'bust'},
#       {u'amount': 5, u'type': u'crest'}],
#      u'prerequisite_requirements': []},
#     {u'code': u'b',
#      u'currency_cost': [{u'amount': 0, u'type': u'gold'},
#       {u'amount': 8, u'type': u'bust'},
#       {u'amount': 10, u'type': u'crest'}],
#      u'prerequisite_requirements': [{u'requirement_code': u'a',
#        u'tree_id': u'abbey.meditation'}]},
#     {u'code': u'c',
#      u'currency_cost': [{u'amount': 0, u'type': u'gold'},
#       {u'amount': 11, u'type': u'bust'},
#       {u'amount': 14, u'type': u'crest'}],
#      u'prerequisite_requirements': [{u'requirement_code': u'b',
#        u'tree_id': u'abbey.meditation'}]},
#     {u'code': u'd',
#      u'currency_cost': [{u'amount': 0, u'type': u'gold'},
#       {u'amount': 15, u'type': u'bust'},
# ...

# %%
# Out:
# 'asdsad'
